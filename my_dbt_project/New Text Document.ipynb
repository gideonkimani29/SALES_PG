# %%
import subprocess
result = subprocess.run(["dbt", "run"], cwd=r"F:\SALES_PG\my_dbt_project", capture_output=True, text=True)
print(result.stdout)
print(result.stderr)
# Out:
# 09:25:23  Running with dbt=1.11.7
# 09:25:24  Registered adapter: postgres=1.10.0
# 09:25:25  Unable to do partial parsing because of a version mismatch
# 09:25:28  [WARNING]: Configuration paths exist in your dbt_project.yml file which do not apply to any resources.
# There are 1 unused configuration paths:
# - models.my_dbt_project.example
# 09:25:29  Found 12 models, 24 data tests, 6 sources, 464 macros
# 09:25:29
# 09:25:29  Concurrency: 1 threads (target='dev')
# 09:25:29
# 09:25:30  1 of 12 START sql view model public.dim_date ................................... [RUN]
# 09:25:30  1 of 12 OK created sql view model public.dim_date .............................. [CREATE VIEW in 0.34s]
# 09:25:30  2 of 12 START sql view model public.stg_categories ............................. [RUN]
# 09:25:30  2 of 12 OK created sql view model public.stg_categories ........................ [CREATE VIEW in 0.12s]
# ...

# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host="localhost",
    dbname="groceries",
    user="postgres",
    password="1189",
    port=5432
)

df = pd.read_sql("SELECT * FROM public.my_first_dbt_model", conn)
df.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_36412\1658047253.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM public.my_first_dbt_model", conn)
#     id
# 0  1.0
# 1  NaN

# %%
# Load the extension
# %load_ext sql

# %%
# Connect to postgres
# %sql postgresql://postgres:1189@localhost:5432/groceries

# %%
# %%sql
# SELECT table_name
# FROM information_schema.tables
# WHERE table_schema = 'public'
# ORDER BY table_name;
# Out:
#  * postgresql://postgres:***@localhost:5432/groceries
# 20 rows affected.
# [('categories',),
#  ('cities',),
#  ('customers',),
#  ('dim_customer',),
#  ('dim_date',),
#  ('dim_employee',),
#  ('dim_location',),
#  ('dim_product',),
#  ('employees',),
#  ('fct_sales',),
#  ('my_first_dbt_model',),
#  ('my_second_dbt_model',),
#  ('products',),
#  ('sales',),
#  ('stg_categories',),
#  ('stg_cities',),
#  ('stg_customers',),
#  ('stg_employees',),
#  ('stg_products',),
#  ('stg_sales',)]

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_schema = 'public'
# AND table_name IN ('sales', 'products', 'customers', 'employees', 'categories', 'cities')
# ORDER BY table_name, ordinal_position;
# Out:
#  * postgresql://postgres:***@localhost:5432/groceries
# 38 rows affected.
# [('category_id', 'integer'),
#  ('category_name', 'character varying'),
#  ('city_id', 'integer'),
#  ('city_name', 'character varying'),
#  ('zipcode', 'character varying'),
#  ('country_id', 'integer'),
#  ('customer_id', 'integer'),
#  ('first_name', 'character varying'),
#  ('middle_initial', 'character'),
#  ('last_name', 'character varying'),
#  ('city_id', 'integer'),
#  ('address', 'character varying'),
#  ('employee_id', 'integer'),
#  ('first_name', 'character varying'),
#  ('middle_initial', 'character'),
#  ('last_name', 'character varying'),
#  ('birth_date', 'date'),
#  ('gender', 'character'),
#  ('city_id', 'integer'),
#  ('hire_date', 'date'),
#  ('product_id', 'integer'),
#  ('product_name', 'character varying'),
#  ('price', 'numeric'),
#  ('category_id', 'integer'),
#  ('class', 'character varying'),
#  ('modify_date', 'date'),
#  ('resistant', 'character varying'),
# ...
